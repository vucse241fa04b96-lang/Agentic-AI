# %%
import ollama
Convo=[]

# %%
def Stream_ollama(prompt):
    Convo.append({'role':'user','content':prompt})
    response=""
    stream=ollama.chat(model='llama3.2',messages=Convo,stream=True)
    for chunk in stream:
        response+=chunk['message']['content']
        print(chunk['message']['content'],end='',flush=True)
    Convo.append({'role':'assisstant','content':response})

# %%
prompt="Explain the python OOPS?"
Stream_ollama(prompt)
# Out:
# **Python Object-Oriented Programming (OOPS)**
#
# Python is a multi-paradigm programming language that supports several object-oriented programming (OOPS) concepts. Here's an overview of the key aspects of Python OOPS:
#
# ### 1. Classes and Objects
#
# *   **Classes**: A class in Python is a blueprint or template for creating objects. It defines a set of attributes (data) and methods (functions).
# *   **Objects**: An object is an instance of a class, which has its own set of attributes and methods.
#
# ```python
# class Car:
#     def __init__(self, brand, model):
#         self.brand = brand
#         self.model = model
#
# my_car = Car('Toyota', 'Camry')
# print(my_car.brand)  # Output: Toyota
# ```
#
# ### 2. Inheritance
#
# *   **Inheritance**: Inheritance is the mechanism by which one class can inherit the properties and behavior of another class.
# *   **Parent Class (Base Class)**: The parent class provides the basic structure and attributes for the child class to build upon.
# *   **Child Class (Derived Class)**: The child class inherits all the attributes and methods from the parent class and can also add new attributes and override existing ones.
#
# ```python
# class ElectricCar(Car):
#     def __init__(self, brand, model, battery_capacity):
#         super().__init__(brand, model)
#         self.battery_capacity = battery_capacity
#
# my_electric_car = ElectricCar('Tesla', 'Model S', 75)
# print(my_electric_car.brand)  # Output: Tesla
# ```
#
# ### 3. Polymorphism
#
# *   **Polymorphism**: Polymorphism is the ability of an object to take on multiple forms, depending on the context in which it's used.
# *   **Method Overriding**: Method overriding occurs when a child class provides a different implementation for a method already defined by its parent class.
# *   **Method Overloading**: Method overloading occurs when multiple methods with the same name can be called with different parameters.
#
# ```python
# class Rectangle:
#     def area(self):
#         pass
#
# class Square(Rectangle):
#     def __init__(self, side_length):
#         self.side_length = side_length
#
#     def area(self):
#         return self.side_length ** 2
#
# rectangle = Rectangle()
# square = Square(4)
# print(rectangle.area())  # Output: 0 (default method)
# print(square.area())  # Output: 16
# ```
#
# ### 4. Encapsulation
#
# *   **Encapsulation**: Encapsulation is the concept of bundling data and its associated methods that operate on that data within a single unit.
# *   **Private Attributes**: Private attributes are defined with a leading underscore, making them inaccessible directly from outside the class.
#
# ```python
# class BankAccount:
#     def __init__(self):
#         self.__balance = 0
#
#     def deposit(self, amount):
#         if amount > 0:
#             self.__balance += amount
#             print(f"Deposited ${amount}. New balance: ${self.__balance}")
#
# account = BankAccount()
# account.deposit(100)  # Output: Deposited $100. New balance: $100
# try:
#     account.__balance = -50
# except AttributeError as e:
#     print(e)  # Output: 'BankAccount' object has no attribute '__balance'
# ```
#
# ### 5. Abstraction
#
# *   **Abstraction**: Abstraction is the concept of showing only necessary information to the outside world while hiding internal implementation details.
# *   **Abstract Base Class (ABC)**: The ABC class provides a way to define an interface or abstract base class that can be inherited by other classes.
#
# ```python
# from abc import ABC, abstractmethod
#
# class AbstractClassExample(ABC):
#     @abstractmethod
#     def do_something(self):
#         pass
#
# class ConcreteClass(AbstractClassExample):
#     def do_something(self):
#         print("Doing something")
#
# instance = ConcreteClass()
# instance.do_something()  # Output: Doing something
# ```
#
# In summary, Python OOPS provides a powerful framework for designing and organizing code, making it easier to write reusable and maintainable software.
